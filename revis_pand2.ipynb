# %% [markdown]
# <a href="https://colab.research.google.com/github/NanMeoli/Revis-o-Pandas/blob/main/revis_pand2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dados = pd.read_csv('/content/dados_funcionarios.csv')

df = pd.DataFrame(dados)
# df.head(10)
# df.tail(5)
# df.columns
# df.info()
# df.describe()
# df[['Nome', 'Setor', 'Salario']]
# df.sort_values('Salario', ascending=False)
# df[df['Setor']=='TI']
# df[df['Salario']>6000]
# df.count()
# df.groupby('Setor').mean('Salario')
# df.groupby('Salario').max()
# df.groupby('Salario').min()
# df[df['Avaliação']>=9]
# df[df['Tempo_Empresa']>5]
# df['Categoria'] = df['Salario'].apply(lambda x: "Alto" if x>6000 else "Normal")
# df[df['Categoria']=='Alto']
# df.groupby('Setor').mean('Avaliação')
# df.groupby('Setor')['Salario'].sum()
# df.loc[df["Tempo_Empresa"].idxmax()]
# df[df['Nome'].str[0]=='A']
# df[df['Nome'].str.endswith('A')]
# df[df['Avaliação'].between(7,9)]
# df.sort_values('Tempo_Empresa')
# df[df['Salario'].between(5000,6000)]
# df['Nome'].str.upper()
# df["Salario"].drop_duplicates()
# df.sort_values(['Setor','Salario'])
# df[df['Setor'].str[0]=='M'].count()
# df.groupby('Setor').sum('RH')
